# %%
from mymodule import divide

print(divide(10,2))
print(__name__)
# Out:
# 5.0
# __main__

# %%
import sys

print(sys.path)
# Out:
# ['E:\\Courses\\Online Practice\\Python\\18_Imports_in_Python', 'C:\\Users\\brigu\\Anaconda3\\envs\\tf\\python37.zip', 'C:\\Users\\brigu\\Anaconda3\\envs\\tf\\DLLs', 'C:\\Users\\brigu\\Anaconda3\\envs\\tf\\lib', 'C:\\Users\\brigu\\Anaconda3\\envs\\tf', '', 'C:\\Users\\brigu\\AppData\\Roaming\\Python\\Python37\\site-packages', 'C:\\Users\\brigu\\Anaconda3\\envs\\tf\\lib\\site-packages', 'C:\\Users\\brigu\\Anaconda3\\envs\\tf\\lib\\site-packages\\win32', 'C:\\Users\\brigu\\Anaconda3\\envs\\tf\\lib\\site-packages\\win32\\lib', 'C:\\Users\\brigu\\Anaconda3\\envs\\tf\\lib\\site-packages\\Pythonwin', 'C:\\Users\\brigu\\Anaconda3\\envs\\tf\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\brigu\\.ipython']

# %%
import mymodule
import sys

print(sys.modules)
# Out:
# {'sys': <module 'sys' (built-in)>, 'builtins': <module 'builtins' (built-in)>, '_frozen_importlib': <module 'importlib._bootstrap' (frozen)>, '_imp': <module '_imp' (built-in)>, '_thread': <module '_thread' (built-in)>, '_warnings': <module '_warnings' (built-in)>, '_weakref': <module '_weakref' (built-in)>, 'zipimport': <module 'zipimport' (built-in)>, '_frozen_importlib_external': <module 'importlib._bootstrap_external' (frozen)>, '_io': <module 'io' (built-in)>, 'marshal': <module 'marshal' (built-in)>, 'nt': <module 'nt' (built-in)>, 'winreg': <module 'winreg' (built-in)>, 'encodings': <module 'encodings' from 'C:\\Users\\brigu\\Anaconda3\\envs\\tf\\lib\\encodings\\__init__.py'>, 'codecs': <module 'codecs' from 'C:\\Users\\brigu\\Anaconda3\\envs\\tf\\lib\\codecs.py'>, '_codecs': <module '_codecs' (built-in)>, 'encodings.aliases': <module 'encodings.aliases' from 'C:\\Users\\brigu\\Anaconda3\\envs\\tf\\lib\\encodings\\aliases.py'>, 'encodings.utf_8': <module 'encodings.utf_8' from
# ...
